# %% [markdown]
# <a href="https://colab.research.google.com/github/RaflyLesmana3003/Linear-regresion/blob/master/latihan_k_nearess_neighbor_(iris).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
from sklearn import linear_model, preprocessing
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
iris = pd.read_csv("/content/drive/Shareddrives/smartlegal collaborative pool/leads-25-06-2021.csv")

print(iris)
# print(iris.target)
# print(iris.target_names)
# print(iris.data.shape)
# Out:
#         id  company_id  client_id  ...  loss_reason  nama_referal   ip
# 0       49         3.0        NaN  ...          NaN           NaN  NaN
# 1       52         3.0        NaN  ...          NaN           NaN  NaN
# 2       53         3.0        NaN  ...          NaN           NaN  NaN
# 3       54         3.0        NaN  ...          NaN           NaN  NaN
# 4       60         3.0        NaN  ...          NaN           NaN  NaN
# ...    ...         ...        ...  ...          ...           ...  ...
# 8969  9478         3.0        NaN  ...          NaN           NaN  NaN
# 8970  9479         3.0        NaN  ...          NaN           NaN  NaN
# 8971  9480         3.0        NaN  ...          NaN           NaN  NaN
# 8972  9481         3.0        NaN  ...          NaN           NaN  NaN
# 8973  9482         3.0        NaN  ...          NaN           NaN  NaN
#
# [8974 rows x 20 columns]

# %%
x = iris.data
y = iris.target

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size=0.2)
k_range = range(1,26)
scores = {}
scores_list = []
for k in k_range:
  model = KNeighborsClassifier(n_neighbors=k)
  model.fit(x_train,y_train)
  acc = model.score(x_test,y_test)
  print("acc:",acc)
  scores_list.append(acc)

# %%
plt.plot(k_range,scores_list)
plt.xlabel("value of k")
plt.ylabel("acc")
# Out:
# Text(0, 0.5, 'acc')

# %%
# The indices of the features that we are plotting
x_index = 0
y_index = 1

# this formatter will label the colorbar with the correct target names
formatter = plt.FuncFormatter(lambda i, *args: iris.target_names[int(i)])

plt.figure(figsize=(5, 4))
plt.scatter(iris.data[:, x_index], iris.data[:, y_index], c=iris.target)
plt.colorbar(ticks=[0, 1, 2], format=formatter)
plt.xlabel(iris.feature_names[x_index])
plt.ylabel(iris.feature_names[y_index])

plt.tight_layout()
plt.show()

predicted = model.predict(x_test)
# print(predicted)
names = ['setosa', 'versicolor', 'virginica']
for x in range(len(predicted)): 
    print("predict:", names[predicted[x]],"data", x_test[x],"actual", names[y_test[x]])

prediksi = model.predict([[6.8,2.8,6.0,1.3]])
print(names[prediksi[0]])
# Out:
# virginica

# %% [markdown]
# visualization

# %%
# import pandas as pd
# import warnings # current version of seaborn generates a bunch of warnings that we'll ignore
# warnings.filterwarnings("ignore")
# import seaborn as sns
# import matplotlib.pyplot as plt
# import matplotlib as mpl
# mpl.rcParams['figure.dpi']= 300
# sns.set(style="white", color_codes=True)
# iris = pd.read_csv("/content/drive/My Drive/machine learning/latihan - k-nearess neighbor (iris)/Iris.csv") # the iris dataset is now a Pandas DataFrame
# #print(iris)

# sns.set(font_scale=2.0) 

# sns.FacetGrid(iris, hue="Species", size=10) \
#     .map(plt.scatter, "SepalLengthCm", "SepalWidthCm", s=150) \
#     .add_legend()

# %%
# The diagonal elements in a pairplot show the histogram by default
# We can update these elements to show other things, such as a kde(kernel density estimate, ядерная оценка плотности)
# sns.pairplot(iris.drop("Id", axis=1), hue="Species", size=3, diag_kind="kde")

# %%
# # kdeplot using seaborn
# sns.set(style='darkgrid')
# setosa = iris.query("Species=='Iris-setosa'")
# versicolor = iris.query("Species=='Iris-versicolor'")
# virginica = iris.query("Species=='Iris-virginica'")
# f, ax = plt.subplots(figsize=(8, 8))
# # ax.set_aspect('equal')
# ax = sns.kdeplot(setosa.SepalWidthCm, setosa.SepalLengthCm, cmap="Greens",
#           shade=True, shade_lowest=False)
# ax = sns.kdeplot(versicolor.SepalWidthCm, versicolor.SepalLengthCm, cmap="Reds",
#           shade=True, shade_lowest=False)
# ax = sns.kdeplot(virginica.SepalWidthCm, virginica.SepalLengthCm, cmap="Blues",
#           shade=True, shade_lowest=False)

# red = sns.color_palette("Reds")[-2]
# blue = sns.color_palette("Blues")[-2]
# green = sns.color_palette("Greens")[-2]
# ax.text(2.5, 8.2, "virginica", size=16, color=blue)
# ax.text(1.8, 6.5, "versicolor", size=16, color=red)
# ax.text(3.8, 4.5, "setosa", size=16, color=green)
